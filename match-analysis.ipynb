# %% [markdown]
# **Import Libraries, load the data**

# %%
import pandas as pd
pd.set_option('mode.use_inf_as_na', True)
from datetime import timedelta
import warnings
import mysql.connector

warnings.filterwarnings("ignore")

connection = mysql.connector.connect(
    port="3307",
    user="root",
    password="dev",
    database="soccer_dwh"
)

cursor = connection.cursor()


#load data (make sure you have downloaded database.sqlite)

matches = pd.read_sql_query("SELECT * from `match_goals_fact`", connection)
leagues = pd.read_sql_query("SELECT * from league_dim", connection)
teams = pd.read_sql_query("SELECT * from team_dim", connection)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns  #Visualization

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

# %%
leages_by_season = pd.read_sql("""SELECT league_dim.country_name, league_dim.name, period as season,
                               count(distinct stage) AS number_of_stages,
                                count(distinct HT.long_name) AS number_of_teams,
                                avg(goal_for) AS avg_home_team_scores, 
                                avg(goal_against) AS avg_away_team_goals, 
                                avg(goal_for-goal_against) AS avg_goal_dif, 
                                avg(goal_for+goal_against) AS avg_goals, 
                                sum(goal_for+goal_against) AS total_goals                                      
                                FROM match_goals_fact
                                JOIN league_dim on league_dim.id = match_goals_fact.league
                                JOIN season_dim on season_dim.id = match_goals_fact.season
                                LEFT JOIN team_dim AS HT on HT.id = match_goals_fact.home_team
                                LEFT JOIN team_dim AS AT on AT.id = match_goals_fact.away_team
                                WHERE league_dim.country_name in ('Spain', 'Germany', 'France', 'Italy', 'England')
                                GROUP BY league_dim.country_name, league_dim.name, season
                                HAVING count(distinct stage) > 10
                                ORDER BY league_dim.country_name, league_dim.name, season DESC
                                ;""", connection)
leages_by_season
# Out:
#    country_name                    name     season  number_of_stages  \
# 0       England  England Premier League  2015/2016                38
# 1       England  England Premier League  2014/2015                38
# 2       England  England Premier League  2013/2014                38
# 3       England  England Premier League  2012/2013                38
# 4       England  England Premier League  2011/2012                38
# 5       England  England Premier League  2010/2011                38
# 6       England  England Premier League  2009/2010                38
# 7       England  England Premier League  2008/2009                38
# 8        France          France Ligue 1  2015/2016                38
# 9        France          France Ligue 1  2014/2015                38
# 10       France          France Ligue 1  2013/2014                38
# 11       France          France Ligue 1  2012/2013                38
# 12       France          France Ligue 1  2011/2012                38
# 13       France          France Ligue 1  2010/2011                38
# 14       France          France Ligue 1  2009/2010                38
# 15       France          France Ligue 1  2008/2009                38
# 16      Germany   Germany 1. Bundesliga  2015/2016                34
# 17      Germany   Germany 1. Bundesliga  2014/2015                34
# 18      Germany   Germany 1. Bundesliga  2013/2014                34
# 19      Germany   Germany 1. Bundesliga  2012/2013                34
# 20      Germany   Germany 1. Bundesliga  2011/2012                34
# 21      Germany   Germany 1. Bundesliga  2010/2011                34
# 22      Germany   Germany 1. Bundesliga  2009/2010                34
# 23      Germany   Germany 1. Bundesliga  2008/2009                34
# 24        Italy           Italy Serie A  2015/2016                38
# 25        Italy           Italy Serie A  2014/2015                38
# 26        Italy           Italy Serie A  2013/2014                38
# 27        Italy           Italy Serie A  2012/2013                38
# 28        Italy           Italy Serie A  2011/2012                38
# 29        Italy           Italy Serie A  2010/2011                38
# 30        Italy           Italy Serie A  2009/2010                38
# 31        Italy           Italy Serie A  2008/2009                38
# 32        Spain         Spain LIGA BBVA  2015/2016                38
# 33        Spain         Spain LIGA BBVA  2014/2015                38
# 34        Spain         Spain LIGA BBVA  2013/2014                38
# 35        Spain         Spain LIGA BBVA  2012/2013                38
# 36        Spain         Spain LIGA BBVA  2011/2012                38
# 37        Spain         Spain LIGA BBVA  2010/2011                38
# 38        Spain         Spain LIGA BBVA  2009/2010                38
# 39        Spain         Spain LIGA BBVA  2008/2009                38
#
#     number_of_teams  avg_home_team_scores  avg_away_team_goals  avg_goal_dif  \
# 0                20                3.1711               2.5605        0.6105
# 1                20                3.0737               2.3053        0.7684
# 2                20                3.5842               2.6921        0.8921
# 3                20                3.3289               2.8316        0.4974
# 4                20                3.3789               2.6316        0.7474
# 5                20                3.4368               2.5421        0.8947
# 6                20                3.6132               2.3342        1.2789
# 7                20                2.8947               2.2237        0.6711
# 8                20                3.0395               2.2921        0.7474
# 9                20                2.8632               2.1474        0.7158
# 10               20                2.9474               2.1605        0.7868
# 11               20                3.0079               2.2316        0.7763
# 12               20                2.9974               2.1421        0.8553
# 13               20                2.7763               2.1026        0.6737
# 14               20                2.9684               2.1974        0.7711
# 15               20                2.6658               2.0447        0.6211
# 16               18                3.0392               2.3791        0.6601
# 17               18                3.1405               2.2745        0.8660
# 18               18                3.5621               2.8562        0.7059
# 19               18                3.2157               2.7092        0.5065
# 20               18                3.3235               2.4150        0.9085
# 21               18                3.1438               2.3562        0.7876
# 22               18                2.8170               2.4216        0.3954
# 23               18                3.5065               2.5065        1.0000
# 24               20                3.2263               2.4316        0.7947
# 25               20                3.3377               2.5831        0.7546
# 26               20                3.3289               2.5921        0.7368
# 27               20                3.1947               2.4632        0.7316
# 28               20                3.4525               2.5028        0.9497
# 29               20                3.1921               2.4868        0.7053
# 30               20                3.3263               2.2079        1.1184
# 31               20                3.3447               2.3000        1.0447
# 32               20                3.5421               2.3868        1.1553
# 33               20                3.4132               2.4316        0.9816
# 34               20                3.4079               2.3395        1.0684
# 35               20                3.2184               2.2553        0.9632
# 36               20                3.8447               2.4789        1.3658
# 37               20                3.5184               2.3921        1.1263
# 38               20                3.4789               2.4763        1.0026
# 39               20                3.6947               2.7421        0.9526
#
#     avg_goals  total_goals
# 0      5.7316       2178.0
# 1      5.3789       2044.0
# 2      6.2763       2385.0
# 3      6.1605       2341.0
# 4      6.0105       2284.0
# 5      5.9789       2272.0
# 6      5.9474       2260.0
# 7      5.1184       1945.0
# 8      5.3316       2026.0
# 9      5.0105       1904.0
# 10     5.1079       1941.0
# 11     5.2395       1991.0
# 12     5.1395       1953.0
# 13     4.8789       1854.0
# 14     5.1658       1963.0
# 15     4.7105       1790.0
# 16     5.4183       1658.0
# 17     5.4150       1657.0
# 18     6.4183       1964.0
# 19     5.9248       1813.0
# 20     5.7386       1756.0
# 21     5.5000       1683.0
# 22     5.2386       1603.0
# 23     6.0131       1840.0
# 24     5.6579       2150.0
# 25     5.9208       2244.0
# 26     5.9211       2250.0
# 27     5.6579       2150.0
# 28     5.9553       2132.0
# 29     5.6789       2158.0
# 30     5.5342       2103.0
# 31     5.6447       2145.0
# 32     5.9289       2253.0
# 33     5.8447       2221.0
# 34     5.7474       2184.0
# 35     5.4737       2080.0
# 36     6.3237       2403.0
# 37     5.9105       2246.0
# 38     5.9553       2263.0
# 39     6.4368       2446.0

# %%
df = pd.DataFrame(index=np.sort(leages_by_season['season'].unique()), columns=leages_by_season['country_name'].unique())

df.loc[:,'Germany'] = list(leages_by_season.loc[leages_by_season['country_name']=='Germany','avg_goals'])
df.loc[:,'Spain']   = list(leages_by_season.loc[leages_by_season['country_name']=='Spain','avg_goals'])
df.loc[:,'France']   = list(leages_by_season.loc[leages_by_season['country_name']=='France','avg_goals'])
df.loc[:,'Italy']   = list(leages_by_season.loc[leages_by_season['country_name']=='Italy','avg_goals'])
df.loc[:,'England']   = list(leages_by_season.loc[leages_by_season['country_name']=='England','avg_goals'])

df.plot(figsize=(12,5),title='Average Goals per Game Over Time')
# Out:
# <Axes: title={'center': 'Average Goals per Game Over Time'}>

# %%
df = pd.DataFrame(index=np.sort(leages_by_season['season'].unique()), columns=leages_by_season['country_name'].unique())

df.loc[:,'Germany'] = list(leages_by_season.loc[leages_by_season['country_name']=='Germany','avg_goal_dif'])
df.loc[:,'Spain']   = list(leages_by_season.loc[leages_by_season['country_name']=='Spain','avg_goal_dif'])
df.loc[:,'France']   = list(leages_by_season.loc[leages_by_season['country_name']=='France','avg_goal_dif'])
df.loc[:,'Italy']   = list(leages_by_season.loc[leages_by_season['country_name']=='Italy','avg_goal_dif'])
df.loc[:,'England']   = list(leages_by_season.loc[leages_by_season['country_name']=='England','avg_goal_dif'])

df.plot(figsize=(12,5),title='Average Goals Difference Home vs Out')
# Out:
# <Axes: title={'center': 'Average Goals Difference Home vs Out'}>

# %% [markdown]
# ****List of Matches****
#
# In this exapmle we will show only the columns that interests us, so instead of * we will use the exact names.
#
# Some of the cells have the same name (Country.name,League.name). We will rename them using AS.
#
# As you can see, this query has much more joins. The reasons is because the DB is designed in a star structure - one table (Match) with all the "performance" and metrics, but only keys and IDs, while all the descriptive information stored in other tables (Country, League, Team)
# And then I am creating different tables for all the leagues from the dataset matches which I'll later store in Matches.

# %%
matches_Spain = pd.read_sql("""SELECT 
                            league_dim.country_name AS country_name, 
                            league_dim.name AS league_name, 
                            period, 
                            stage, 
                            date,
                            HT.long_name AS  home_team,
                            AT.long_name AS away_team,
                            goal_for, 
                            goal_against                                        
                                FROM match_goals_fact
                                JOIN league_dim on league_dim.id = match_goals_fact.league
                                JOIN season_dim on season_dim.id = match_goals_fact.season
                                LEFT JOIN team_dim AS HT on HT.id = match_goals_fact.home_team
                                LEFT JOIN team_dim AS AT on AT.id = match_goals_fact.away_team
                                WHERE country_name = 'Spain' 
                                ORDER by date
                               ;""", connection)
#matches.head() #It gives us first 5 matches in Spanish League in season 2008/09

matches_Eng = pd.read_sql("""SELECT 
                            league_dim.country_name AS country_name, 
                            league_dim.name AS league_name, 
                            period, 
                            stage, 
                            date,
                            HT.long_name AS  home_team,
                            AT.long_name AS away_team,
                            goal_for, 
                            goal_against                                         
                                FROM match_goals_fact
                                JOIN league_dim on league_dim.id = match_goals_fact.league
                                JOIN season_dim on season_dim.id = match_goals_fact.season
                                LEFT JOIN team_dim AS HT on HT.id = match_goals_fact.home_team
                                LEFT JOIN team_dim AS AT on AT.id = match_goals_fact.away_team
                                WHERE country_name = 'England' 
                                ORDER by date
                               ;""", connection)

matches_Ger = pd.read_sql("""SELECT 
                            league_dim.country_name AS country_name, 
                            league_dim.name AS league_name, 
                            period, 
                            stage, 
                            date,
                            HT.long_name AS  home_team,
                            AT.long_name AS away_team,
                            goal_for, 
                            goal_against                                          
                                FROM match_goals_fact
                                JOIN league_dim on league_dim.id = match_goals_fact.league
                                JOIN season_dim on season_dim.id = match_goals_fact.season
                                LEFT JOIN team_dim AS HT on HT.id = match_goals_fact.home_team
                                LEFT JOIN team_dim AS AT on AT.id = match_goals_fact.away_team
                                WHERE country_name = 'Germany' 
                                ORDER by date
                               ;""", connection)

matches_Por = pd.read_sql("""SELECT 
                            league_dim.country_name AS country_name, 
                            league_dim.name AS league_name, 
                            period, 
                            stage, 
                            date,
                            HT.long_name AS  home_team,
                            AT.long_name AS away_team,
                            goal_for, 
                            goal_against                                         
                                FROM match_goals_fact
                                JOIN league_dim on league_dim.id = match_goals_fact.league
                                JOIN season_dim on season_dim.id = match_goals_fact.season
                                LEFT JOIN team_dim AS HT on HT.id = match_goals_fact.home_team
                                LEFT JOIN team_dim AS AT on AT.id = match_goals_fact.away_team
                                WHERE country_name = 'Portugal' 
                                ORDER by date
                               ;""", connection)

matches_Italy = pd.read_sql("""SELECT 
                            league_dim.country_name AS country_name, 
                            league_dim.name AS league_name, 
                            period, 
                            stage, 
                            date,
                            HT.long_name AS  home_team,
                            AT.long_name AS away_team,
                            goal_for, 
                            goal_against                                        
                                FROM match_goals_fact
                                JOIN league_dim on league_dim.id = match_goals_fact.league
                                JOIN season_dim on season_dim.id = match_goals_fact.season
                                LEFT JOIN team_dim AS HT on HT.id = match_goals_fact.home_team
                                LEFT JOIN team_dim AS AT on AT.id = match_goals_fact.away_team
                                WHERE country_name = 'Italy' 
                                ORDER by date
                               ;""", connection)

matches_France = pd.read_sql("""SELECT 
                            league_dim.country_name AS country_name, 
                            league_dim.name AS league_name, 
                            period, 
                            stage, 
                            date,
                            HT.long_name AS  home_team,
                            AT.long_name AS away_team,
                            goal_for, 
                            goal_against                                         
                                FROM match_goals_fact
                                JOIN league_dim on league_dim.id = match_goals_fact.league
                                JOIN season_dim on season_dim.id = match_goals_fact.season
                                LEFT JOIN team_dim AS HT on HT.id = match_goals_fact.home_team
                                LEFT JOIN team_dim AS AT on AT.id = match_goals_fact.away_team
                                WHERE country_name = 'France' 
                                ORDER by date
                               ;""", connection)

matches_Bel = pd.read_sql("""SELECT 
                            league_dim.country_name AS country_name, 
                            league_dim.name AS league_name, 
                            period, 
                            stage, 
                            date,
                            HT.long_name AS  home_team,
                            AT.long_name AS away_team,
                            goal_for, 
                            goal_against                                         
                                FROM match_goals_fact
                                JOIN league_dim on league_dim.id = match_goals_fact.league
                                JOIN season_dim on season_dim.id = match_goals_fact.season
                                LEFT JOIN team_dim AS HT on HT.id = match_goals_fact.home_team
                                LEFT JOIN team_dim AS AT on AT.id = match_goals_fact.away_team
                                WHERE country_name = 'Belgium' 
                                ORDER by date
                               ;""", connection)

matches_Ned = pd.read_sql("""SELECT 
                            league_dim.country_name AS country_name, 
                            league_dim.name AS league_name, 
                            period, 
                            stage, 
                            date,
                            HT.long_name AS  home_team,
                            AT.long_name AS away_team,
                            goal_for, 
                            goal_against                                         
                                FROM match_goals_fact
                                JOIN league_dim on league_dim.id = match_goals_fact.league
                                JOIN season_dim on season_dim.id = match_goals_fact.season
                                LEFT JOIN team_dim AS HT on HT.id = match_goals_fact.home_team
                                LEFT JOIN team_dim AS AT on AT.id = match_goals_fact.away_team
                                WHERE country_name = 'Netherlands' 
                                ORDER by date
                               ;""", connection)

matches_Pol = pd.read_sql("""SELECT
                            league_dim.country_name AS country_name, 
                            league_dim.name AS league_name, 
                            period, 
                            stage, 
                            date,
                            HT.long_name AS  home_team,
                            AT.long_name AS away_team,
                            goal_for, 
                            goal_against                                       
                                FROM match_goals_fact
                                JOIN league_dim on league_dim.id = match_goals_fact.league
                                JOIN season_dim on season_dim.id = match_goals_fact.season
                                LEFT JOIN team_dim AS HT on HT.id = match_goals_fact.home_team
                                LEFT JOIN team_dim AS AT on AT.id = match_goals_fact.away_team
                                WHERE country_name = 'Poland' 
                                ORDER by date
                               ;""", connection)

matches_Scot = pd.read_sql("""SELECT
                            league_dim.country_name AS country_name, 
                            league_dim.name AS league_name, 
                            period, 
                            stage, 
                            date,
                            HT.long_name AS  home_team,
                            AT.long_name AS away_team,
                            goal_for, 
                            goal_against                                        
                                FROM match_goals_fact
                                JOIN league_dim on league_dim.id = match_goals_fact.league
                                JOIN season_dim on season_dim.id = match_goals_fact.season
                                LEFT JOIN team_dim AS HT on HT.id = match_goals_fact.home_team
                                LEFT JOIN team_dim AS AT on AT.id = match_goals_fact.away_team
                                WHERE country_name = 'Scotland' 
                                ORDER by date
                               ;""", connection)

matches_Swt = pd.read_sql("""SELECT
                            league_dim.country_name AS country_name, 
                            league_dim.name AS league_name, 
                            period, 
                            stage, 
                            date,
                            HT.long_name AS  home_team,
                            AT.long_name AS away_team,
                            goal_for, 
                            goal_against                                        
                                FROM match_goals_fact
                                JOIN league_dim on league_dim.id = match_goals_fact.league
                                JOIN season_dim on season_dim.id = match_goals_fact.season
                                LEFT JOIN team_dim AS HT on HT.id = match_goals_fact.home_team
                                LEFT JOIN team_dim AS AT on AT.id = match_goals_fact.away_team
                                WHERE country_name = 'Switzerland' 
                                ORDER by date
                               ;""", connection)

# %% [markdown]
# **Making a list of all the leagues matches**
#
# So here we created a list of matches in all respective leagues so that we can iterate over all the leagues to do other calculations easily.

# %%
matches = [matches_Spain,matches_Eng,matches_Italy,matches_Ger,matches_Por,matches_France,matches_Swt,matches_Pol,matches_Scot,matches_Ned,matches_Bel]
matches
# Out:
# [     country_name      league_name     period  stage        date  \
#  0           Spain  Spain LIGA BBVA  2008/2009      1  2008-08-30
#  1           Spain  Spain LIGA BBVA  2008/2009      1  2008-08-30
#  2           Spain  Spain LIGA BBVA  2008/2009      1  2008-08-31
#  3           Spain  Spain LIGA BBVA  2008/2009      1  2008-08-31
#  4           Spain  Spain LIGA BBVA  2008/2009      1  2008-08-31
#  ...           ...              ...        ...    ...         ...
#  3035        Spain  Spain LIGA BBVA  2015/2016     38  2016-05-15
#  3036        Spain  Spain LIGA BBVA  2015/2016     38  2016-05-15
#  3037        Spain  Spain LIGA BBVA  2015/2016     38  2016-05-15
#  3038        Spain  Spain LIGA BBVA  2015/2016     38  2016-05-15
#  3039        Spain  Spain LIGA BBVA  2015/2016     38  2016-05-15
#
#                        home_team        away_team  goal_for  goal_against
#  0                   Valencia CF     RCD Mallorca         3             0
#  1                  RCD Espanyol  Real Valladolid         1             0
#  2                    CA Osasuna    Villarreal CF         1             1
#  3     RC Deportivo de La Coruña   Real Madrid CF         2             1
#  4                   CD Numancia     FC Barcelona         1             0
#  ...                         ...              ...       ...           ...
#  3035     Real Sporting de Gijón    Villarreal CF         2             0
#  3036        Real Betis Balompié        Getafe CF         2             1
#  3037               RCD Espanyol         SD Eibar         5             2
#  3038                  Málaga CF    UD Las Palmas         7             2
#  3039             Rayo Vallecano       Levante UD         3             1
#
#  [3040 rows x 9 columns],
#       country_name             league_name     period  stage        date  \
#  0         England  England Premier League  2008/2009      1  2008-08-16
#  1         England  England Premier League  2008/2009      1  2008-08-16
#  2         England  England Premier League  2008/2009      1  2008-08-16
#  3         England  England Premier League  2008/2009      1  2008-08-16
#  4         England  England Premier League  2008/2009      1  2008-08-16
#  ...           ...                     ...        ...    ...         ...
#  3035      England  England Premier League  2015/2016     38  2016-05-15
#  3036      England  England Premier League  2015/2016     38  2016-05-15
#  3037      England  England Premier League  2015/2016     38  2016-05-15
#  3038      England  England Premier League  2015/2016     38  2016-05-15
#  3039      England  England Premier League  2015/2016     38  2016-05-17
#
#                home_team             away_team  goal_for  goal_against
#  0               Arsenal  West Bromwich Albion         4             0
#  1            Sunderland             Liverpool         0             4
#  2       West Ham United        Wigan Athletic         6             2
#  3               Everton      Blackburn Rovers         2             6
#  4         Middlesbrough     Tottenham Hotspur         4             2
#  ...                 ...                   ...       ...           ...
#  3035            Chelsea        Leicester City         3             3
#  3036       Swansea City       Manchester City         4             2
#  3037        Southampton        Crystal Palace         8             3
#  3038            Watford            Sunderland         2             2
#  3039  Manchester United           Bournemouth         4             2
#
#  [3040 rows x 9 columns],
#       country_name    league_name     period  stage        date      home_team  \
#  0           Italy  Italy Serie A  2008/2009      1  2008-08-30      Sampdoria
#  1           Italy  Italy Serie A  2008/2009      1  2008-08-30        Udinese
#  2           Italy  Italy Serie A  2008/2009      1  2008-08-31       Atalanta
#  3           Italy  Italy Serie A  2008/2009      1  2008-08-31       Cagliari
#  4           Italy  Italy Serie A  2008/2009      1  2008-08-31        Catania
#  ...           ...            ...        ...    ...         ...            ...
#  3012        Italy  Italy Serie A  2015/2016     38  2016-05-15          Genoa
#  3013        Italy  Italy Serie A  2015/2016     38  2016-05-15  Chievo Verona
#  3014        Italy  Italy Serie A  2015/2016     38  2016-05-15        Udinese
#  3015        Italy  Italy Serie A  2015/2016     38  2016-05-15        Palermo
#  3016        Italy  Italy Serie A  2015/2016     38  2016-05-15         Empoli
#
#            away_team  goal_for  goal_against
#  0             Inter         1             1
#  1           Palermo         3             1
#  2             Siena         1             0
#  3             Lazio         1             4
#  4             Genoa         1             0
#  ...             ...       ...           ...
#  3012       Atalanta         3             5
#  3013        Bologna         0             0
#  3014          Carpi         1             2
#  3015  Hellas Verona         5             2
#  3016         Torino         2             1
#
#  [3017 rows x 9 columns],
#       country_name            league_name     period  stage        date  \
#  0         Germany  Germany 1. Bundesliga  2008/2009      1  2008-08-15
#  1         Germany  Germany 1. Bundesliga  2008/2009      1  2008-08-16
#  2         Germany  Germany 1. Bundesliga  2008/2009      1  2008-08-16
#  3         Germany  Germany 1. Bundesliga  2008/2009      1  2008-08-16
#  4         Germany  Germany 1. Bundesliga  2008/2009      1  2008-08-16
#  ...           ...                    ...        ...    ...         ...
#  2443      Germany  Germany 1. Bundesliga  2015/2016     34  2016-05-14
#  2444      Germany  Germany 1. Bundesliga  2015/2016     34  2016-05-14
#  2445      Germany  Germany 1. Bundesliga  2015/2016     34  2016-05-14
#  2446      Germany  Germany 1. Bundesliga  2015/2016     34  2016-05-14
#  2447      Germany  Germany 1. Bundesliga  2015/2016     34  2016-05-14
#
#                    home_team                 away_team  goal_for  goal_against
#  0          FC Bayern Munich              Hamburger SV         6             3
#  1       Bayer 04 Leverkusen         Borussia Dortmund         7             5
#  2             FC Schalke 04               Hannover 96         4             0
#  3             VfL Wolfsburg                1. FC Köln         4             3
#  4     DSC Arminia Bielefeld          SV Werder Bremen         4             6
#  ...                     ...                       ...       ...           ...
#  2443       SV Werder Bremen       Eintracht Frankfurt         7             2
#  2444    TSG 1899 Hoffenheim             FC Schalke 04         1             4
#  2445        1. FSV Mainz 05         Hertha BSC Berlin         0             0
#  2446            FC Augsburg              Hamburger SV         1             3
#  2447        SV Darmstadt 98  Borussia Mönchengladbach         0             2
#
#  [2448 rows x 9 columns],
#       country_name               league_name     period  stage        date  \
#  0        Portugal  Portugal Liga ZON Sagres  2008/2009      1  2008-08-22
#  1        Portugal  Portugal Liga ZON Sagres  2008/2009      1  2008-08-23
#  2        Portugal  Portugal Liga ZON Sagres  2008/2009      1  2008-08-24
#  3        Portugal  Portugal Liga ZON Sagres  2008/2009      1  2008-08-24
#  4        Portugal  Portugal Liga ZON Sagres  2008/2009      1  2008-08-24
#  ...           ...                       ...        ...    ...         ...
#  1863     Portugal  Portugal Liga ZON Sagres  2015/2016     34  2016-05-14
#  1864     Portugal  Portugal Liga ZON Sagres  2015/2016     34  2016-05-14
#  1865     Portugal  Portugal Liga ZON Sagres  2015/2016     34  2016-05-15
#  1866     Portugal  Portugal Liga ZON Sagres  2015/2016     34  2016-05-15
#  1867     Portugal  Portugal Liga ZON Sagres  2015/2016     34  2016-05-15
#
#                   home_team             away_team  goal_for  goal_against
#  0        Vitória Guimarães       Vitória Setúbal         1             1
#  1     FC Paços de Ferreira              SC Braga         0             2
#  2                 FC Porto      CF Os Belenenses         2             0
#  3               Rio Ave FC            SL Benfica         1             1
#  4               Leixões SC           CD Nacional         1             3
#  ...                    ...                   ...       ...           ...
#  1863       Vitória Setúbal  FC Paços de Ferreira         0             0
#  1864             FC Arouca     Vitória Guimarães         5             2
#  1865              SC Braga           Sporting CP         0             4
#  1866            SL Benfica           CD Nacional         4             1
#  1867         Moreirense FC           CS Marítimo         3             2
#
#  [1868 rows x 9 columns],
#       country_name     league_name     period  stage        date  \
#  0          France  France Ligue 1  2008/2009      1  2008-08-09
#  1          France  France Ligue 1  2008/2009      1  2008-08-09
#  2          France  France Ligue 1  2008/2009      1  2008-08-09
#  3          France  France Ligue 1  2008/2009      1  2008-08-09
#  4          France  France Ligue 1  2008/2009      1  2008-08-09
#  ...           ...             ...        ...    ...         ...
#  3035       France  France Ligue 1  2015/2016     38  2016-05-14
#  3036       France  France Ligue 1  2015/2016     38  2016-05-14
#  3037       France  France Ligue 1  2015/2016     38  2016-05-14
#  3038       France  France Ligue 1  2015/2016     38  2016-05-14
#  3039       France  France Ligue 1  2015/2016     38  2016-05-14
#
#                    home_team               away_team  goal_for  goal_against
#  0                AJ Auxerre               FC Nantes         2             2
#  1     Girondins de Bordeaux                 SM Caen         4             1
#  2               Le Havre AC                OGC Nice         1             1
#  3                Le Mans FC              FC Lorient         1             1
#  4                 AS Monaco     Paris Saint-Germain         2             1
#  ...                     ...                     ...       ...           ...
#  3035       AS Saint-Étienne              LOSC Lille         0             1
#  3036         Stade de Reims      Olympique Lyonnais         4             1
#  3037           ES Troyes AC  Olympique de Marseille         1             1
#  3038   En Avant de Guingamp                OGC Nice         2             3
#  3039             Angers SCO             Toulouse FC         2             4
#
#  [3040 rows x 9 columns],
#       country_name               league_name     period  stage        date  \
#  0     Switzerland  Switzerland Super League  2008/2009      1  2008-07-18
#  1     Switzerland  Switzerland Super League  2008/2009      1  2008-07-19
#  2     Switzerland  Switzerland Super League  2008/2009      1  2008-07-20
#  3     Switzerland  Switzerland Super League  2008/2009      1  2008-07-20
#  4     Switzerland  Switzerland Super League  2008/2009      2  2008-07-23
#  ...           ...                       ...        ...    ...         ...
#  1381  Switzerland  Switzerland Super League  2015/2016     35  2016-05-22
#  1382  Switzerland  Switzerland Super League  2015/2016     36  2016-05-25
#  1383  Switzerland  Switzerland Super League  2015/2016     36  2016-05-25
#  1384  Switzerland  Switzerland Super League  2015/2016     36  2016-05-25
#  1385  Switzerland  Switzerland Super League  2015/2016     36  2016-05-25
#
#              home_team                away_team  goal_for  goal_against
#  0      BSC Young Boys                 FC Basel         1             2
#  1            FC Aarau                  FC Sion         5             2
#  2           FC Luzern                 FC Vaduz         1             3
#  3     Neuchâtel Xamax                FC Zürich         1             2
#  4       AC Bellinzona          Neuchâtel Xamax         1             2
#  ...               ...                      ...       ...           ...
#  1381    FC St. Gallen                FC Luzern         5             7
#  1382         FC Basel  Grasshopper Club Zürich         1             2
#  1383        FC Luzern                  FC Sion         9             2
#  1384        FC Zürich                 FC Vaduz         5             4
#  1385          FC Thun           BSC Young Boys         7             6
#
#  [1386 rows x 9 columns],
#       country_name         league_name     period  stage        date  \
#  0          Poland  Poland Ekstraklasa  2008/2009      1  2008-08-08
#  1          Poland  Poland Ekstraklasa  2008/2009      1  2008-08-08
#  2          Poland  Poland Ekstraklasa  2008/2009      1  2008-08-09
#  3          Poland  Poland Ekstraklasa  2008/2009      1  2008-08-09
#  4          Poland  Poland Ekstraklasa  2008/2009      1  2008-08-09
#  ...           ...                 ...        ...    ...         ...
#  1885       Poland  Poland Ekstraklasa  2015/2016     30  2016-04-09
#  1886       Poland  Poland Ekstraklasa  2015/2016     30  2016-04-09
#  1887       Poland  Poland Ekstraklasa  2015/2016     30  2016-04-09
#  1888       Poland  Poland Ekstraklasa  2015/2016     30  2016-04-09
#  1889       Poland  Poland Ekstraklasa  2015/2016     30  2016-04-09
#
#             home_team              away_team  goal_for  goal_against
#  0     Legia Warszawa            P. Warszawa         4             2
#  1        Lech Poznań          GKS Bełchatów         5             3
#  2       Wisła Kraków          Polonia Bytom         3             1
#  3      Śląsk Wrocław          Lechia Gdańsk         5             1
#  4        Widzew Łódź         Odra Wodzisław         1             2
#  ...              ...                    ...       ...           ...
#  1885   Lechia Gdańsk           Ruch Chorzów         2             0
#  1886   Piast Gliwice  Jagiellonia Białystok         2             0
#  1887   Korona Kielce          Polonia Bytom         2             1
#  1888  Pogoń Szczecin         Legia Warszawa         0             0
#  1889   Górnik Łęczna            Lech Poznań         0             1
#
#  [1890 rows x 9 columns],
#       country_name              league_name     period  stage        date  \
#  0        Scotland  Scotland Premier League  2008/2009      1  2008-08-09
#  1        Scotland  Scotland Premier League  2008/2009      1  2008-08-09
#  2        Scotland  Scotland Premier League  2008/2009      1  2008-08-09
#  3        Scotland  Scotland Premier League  2008/2009      1  2008-08-09
#  4        Scotland  Scotland Premier League  2008/2009      1  2008-08-10
#  ...           ...                      ...        ...    ...         ...
#  1819     Scotland  Scotland Premier League  2015/2016     38  2016-05-14
#  1820     Scotland  Scotland Premier League  2015/2016     38  2016-05-14
#  1821     Scotland  Scotland Premier League  2015/2016     38  2016-05-15
#  1822     Scotland  Scotland Premier League  2015/2016     38  2016-05-15
#  1823     Scotland  Scotland Premier League  2015/2016     38  2016-05-15
#
#                           home_team                     away_team  goal_for  \
#  0                          Falkirk                       Rangers         1
#  1              Heart of Midlothian                    Motherwell         5
#  2                       Kilmarnock                     Hibernian         2
#  3                         Aberdeen  Inverness Caledonian Thistle         1
#  4                           Celtic                    St. Mirren         6
#  ...                            ...                           ...       ...
#  1819  Inverness Caledonian Thistle                     Dundee FC         6
#  1820          Partick Thistle F.C.        Hamilton Academical FC         2
#  1821           Heart of Midlothian              St. Johnstone FC         3
#  1822                      Aberdeen                Ross County FC         0
#  1823                        Celtic                    Motherwell        10
#
#        goal_against
#  0                3
#  1                3
#  2                0
#  3                3
#  4                4
#  ...            ...
#  1819             3
#  1820             2
#  1821             3
#  1822             5
#  1823             2
#
#  [1824 rows x 9 columns],
#       country_name             league_name     period  stage        date  \
#  0     Netherlands  Netherlands Eredivisie  2008/2009      1  2008-08-29
#  1     Netherlands  Netherlands Eredivisie  2008/2009      1  2008-08-30
#  2     Netherlands  Netherlands Eredivisie  2008/2009      1  2008-08-30
#  3     Netherlands  Netherlands Eredivisie  2008/2009      1  2008-08-30
#  4     Netherlands  Netherlands Eredivisie  2008/2009      1  2008-08-30
#  ...           ...                     ...        ...    ...         ...
#  2409  Netherlands  Netherlands Eredivisie  2015/2016     34  2016-05-08
#  2410  Netherlands  Netherlands Eredivisie  2015/2016     34  2016-05-08
#  2411  Netherlands  Netherlands Eredivisie  2015/2016     34  2016-05-08
#  2412  Netherlands  Netherlands Eredivisie  2015/2016     34  2016-05-08
#  2413  Netherlands  Netherlands Eredivisie  2015/2016     34  2016-05-08
#
#               home_team      away_team  goal_for  goal_against
#  0              Vitesse   FC Groningen         0             4
#  1     Roda JC Kerkrade      FC Twente         1             1
#  2            Willem II           Ajax         2             1
#  3               N.E.C.  De Graafschap         2             0
#  4           FC Utrecht            PSV         1             5
#  ...                ...            ...       ...           ...
#  2409        FC Utrecht             AZ         1             3
#  2410         Feyenoord         N.E.C.         1             0
#  2411      ADO Den Haag  SC Heerenveen         1             1
#  2412        PEC Zwolle            PSV         1             3
#  2413        SC Cambuur      Excelsior         0             2
#
#  [2414 rows x 9 columns],
#       country_name             league_name     period  stage        date  \
#  0         Belgium  Belgium Jupiler League  2008/2009      1  2008-08-16
#  1         Belgium  Belgium Jupiler League  2008/2009      1  2008-08-16
#  2         Belgium  Belgium Jupiler League  2008/2009      1  2008-08-16
#  3         Belgium  Belgium Jupiler League  2008/2009      1  2008-08-16
#  4         Belgium  Belgium Jupiler League  2008/2009      1  2008-08-17
#  ...           ...                     ...        ...    ...         ...
#  1657      Belgium  Belgium Jupiler League  2015/2016     30  2016-03-13
#  1658      Belgium  Belgium Jupiler League  2015/2016     30  2016-03-13
#  1659      Belgium  Belgium Jupiler League  2015/2016     30  2016-03-13
#  1660      Belgium  Belgium Jupiler League  2015/2016     30  2016-03-13
#  1661      Belgium  Belgium Jupiler League  2015/2016     30  2016-03-13
#
#                  home_team           away_team  goal_for  goal_against
#  0        SV Zulte-Waregem    Sporting Lokeren         0             0
#  1       KSV Cercle Brugge      RSC Anderlecht         2             4
#  2           KSV Roeselare         KV Kortrijk         3             3
#  3            KVC Westerlo  Sporting Charleroi         2             0
#  4                KRC Genk        Beerschot AC         2             1
#  ...                   ...                 ...       ...           ...
#  1657          KV Mechelen   Standard de Liège         4             0
#  1658         KVC Westerlo    Waasland-Beveren         1             0
#  1659   Sporting Charleroi            KAA Gent         1             1
#  1660    Sint-Truidense VV    Sporting Lokeren         1             1
#  1661  Oud-Heverlee Leuven      Club Brugge KV         0             1
#
#  [1662 rows x 9 columns]]

# %%
def goal_diff(fun):
    for i in fun:
        i['goal_diff'] = i['goal_for']-i['goal_against']
        print(i.tail())

goal_diff(matches)
# Out:
#      country_name      league_name     period  stage        date  \
# 3035        Spain  Spain LIGA BBVA  2015/2016     38  2016-05-15
# 3036        Spain  Spain LIGA BBVA  2015/2016     38  2016-05-15
# 3037        Spain  Spain LIGA BBVA  2015/2016     38  2016-05-15
# 3038        Spain  Spain LIGA BBVA  2015/2016     38  2016-05-15
# 3039        Spain  Spain LIGA BBVA  2015/2016     38  2016-05-15
#
#                    home_team      away_team  goal_for  goal_against  goal_diff
# 3035  Real Sporting de Gijón  Villarreal CF         2             0          2
# 3036     Real Betis Balompié      Getafe CF         2             1          1
# 3037            RCD Espanyol       SD Eibar         5             2          3
# 3038               Málaga CF  UD Las Palmas         7             2          5
# 3039          Rayo Vallecano     Levante UD         3             1          2
#      country_name             league_name     period  stage        date  \
# 3035      England  England Premier League  2015/2016     38  2016-05-15
# 3036      England  England Premier League  2015/2016     38  2016-05-15
# 3037      England  England Premier League  2015/2016     38  2016-05-15
# 3038      England  England Premier League  2015/2016     38  2016-05-15
# 3039      England  England Premier League  2015/2016     38  2016-05-17
#
#               home_team        away_team  goal_for  goal_against  goal_diff
# 3035            Chelsea   Leicester City         3             3          0
# 3036       Swansea City  Manchester City         4             2          2
# 3037        Southampton   Crystal Palace         8             3          5
# 3038            Watford       Sunderland         2             2          0
# 3039  Manchester United      Bournemouth         4             2          2
#      country_name    league_name     period  stage        date      home_team  \
# 3012        Italy  Italy Serie A  2015/2016     38  2016-05-15          Genoa
# 3013        Italy  Italy Serie A  2015/2016     38  2016-05-15  Chievo Verona
# 3014        Italy  Italy Serie A  2015/2016     38  2016-05-15        Udinese
# 3015        Italy  Italy Serie A  2015/2016     38  2016-05-15        Palermo
# 3016        Italy  Italy Serie A  2015/2016     38  2016-05-15         Empoli
#
#           away_team  goal_for  goal_against  goal_diff
# 3012       Atalanta         3             5         -2
# 3013        Bologna         0             0          0
# 3014          Carpi         1             2         -1
# 3015  Hellas Verona         5             2          3
# 3016         Torino         2             1          1
#      country_name            league_name     period  stage        date  \
# 2443      Germany  Germany 1. Bundesliga  2015/2016     34  2016-05-14
# 2444      Germany  Germany 1. Bundesliga  2015/2016     34  2016-05-14
# 2445      Germany  Germany 1. Bundesliga  2015/2016     34  2016-05-14
# 2446      Germany  Germany 1. Bundesliga  2015/2016     34  2016-05-14
# 2447      Germany  Germany 1. Bundesliga  2015/2016     34  2016-05-14
#
#                 home_team                 away_team  goal_for  goal_against  \
# 2443     SV Werder Bremen       Eintracht Frankfurt         7             2
# 2444  TSG 1899 Hoffenheim             FC Schalke 04         1             4
# 2445      1. FSV Mainz 05         Hertha BSC Berlin         0             0
# 2446          FC Augsburg              Hamburger SV         1             3
# 2447      SV Darmstadt 98  Borussia Mönchengladbach         0             2
#
#       goal_diff
# 2443          5
# 2444         -3
# 2445          0
# 2446         -2
# 2447         -2
#      country_name               league_name     period  stage        date  \
# 1863     Portugal  Portugal Liga ZON Sagres  2015/2016     34  2016-05-14
# 1864     Portugal  Portugal Liga ZON Sagres  2015/2016     34  2016-05-14
# 1865     Portugal  Portugal Liga ZON Sagres  2015/2016     34  2016-05-15
# 1866     Portugal  Portugal Liga ZON Sagres  2015/2016     34  2016-05-15
# 1867     Portugal  Portugal Liga ZON Sagres  2015/2016     34  2016-05-15
#
#             home_team             away_team  goal_for  goal_against  goal_diff
# 1863  Vitória Setúbal  FC Paços de Ferreira         0             0          0
# 1864        FC Arouca     Vitória Guimarães         5             2          3
# 1865         SC Braga           Sporting CP         0             4         -4
# 1866       SL Benfica           CD Nacional         4             1          3
# 1867    Moreirense FC           CS Marítimo         3             2          1
#      country_name     league_name     period  stage        date  \
# 3035       France  France Ligue 1  2015/2016     38  2016-05-14
# 3036       France  France Ligue 1  2015/2016     38  2016-05-14
# 3037       France  France Ligue 1  2015/2016     38  2016-05-14
# 3038       France  France Ligue 1  2015/2016     38  2016-05-14
# 3039       France  France Ligue 1  2015/2016     38  2016-05-14
#
#                  home_team               away_team  goal_for  goal_against  \
# 3035      AS Saint-Étienne              LOSC Lille         0             1
# 3036        Stade de Reims      Olympique Lyonnais         4             1
# 3037          ES Troyes AC  Olympique de Marseille         1             1
# 3038  En Avant de Guingamp                OGC Nice         2             3
# 3039            Angers SCO             Toulouse FC         2             4
#
#       goal_diff
# 3035         -1
# 3036          3
# 3037          0
# 3038         -1
# 3039         -2
#      country_name               league_name     period  stage        date  \
# 1381  Switzerland  Switzerland Super League  2015/2016     35  2016-05-22
# 1382  Switzerland  Switzerland Super League  2015/2016     36  2016-05-25
# 1383  Switzerland  Switzerland Super League  2015/2016     36  2016-05-25
# 1384  Switzerland  Switzerland Super League  2015/2016     36  2016-05-25
# 1385  Switzerland  Switzerland Super League  2015/2016     36  2016-05-25
#
#           home_team                away_team  goal_for  goal_against  \
# 1381  FC St. Gallen                FC Luzern         5             7
# 1382       FC Basel  Grasshopper Club Zürich         1             2
# 1383      FC Luzern                  FC Sion         9             2
# 1384      FC Zürich                 FC Vaduz         5             4
# 1385        FC Thun           BSC Young Boys         7             6
#
#       goal_diff
# 1381         -2
# 1382         -1
# 1383          7
# 1384          1
# 1385          1
#      country_name         league_name     period  stage        date  \
# 1885       Poland  Poland Ekstraklasa  2015/2016     30  2016-04-09
# 1886       Poland  Poland Ekstraklasa  2015/2016     30  2016-04-09
# 1887       Poland  Poland Ekstraklasa  2015/2016     30  2016-04-09
# 1888       Poland  Poland Ekstraklasa  2015/2016     30  2016-04-09
# 1889       Poland  Poland Ekstraklasa  2015/2016     30  2016-04-09
#
#            home_team              away_team  goal_for  goal_against  goal_diff
# 1885   Lechia Gdańsk           Ruch Chorzów         2             0          2
# 1886   Piast Gliwice  Jagiellonia Białystok         2             0          2
# 1887   Korona Kielce          Polonia Bytom         2             1          1
# 1888  Pogoń Szczecin         Legia Warszawa         0             0          0
# 1889   Górnik Łęczna            Lech Poznań         0             1         -1
#      country_name              league_name     period  stage        date  \
# 1819     Scotland  Scotland Premier League  2015/2016     38  2016-05-14
# 1820     Scotland  Scotland Premier League  2015/2016     38  2016-05-14
# 1821     Scotland  Scotland Premier League  2015/2016     38  2016-05-15
# 1822     Scotland  Scotland Premier League  2015/2016     38  2016-05-15
# 1823     Scotland  Scotland Premier League  2015/2016     38  2016-05-15
#
#                          home_team               away_team  goal_for  \
# 1819  Inverness Caledonian Thistle               Dundee FC         6
# 1820          Partick Thistle F.C.  Hamilton Academical FC         2
# 1821           Heart of Midlothian        St. Johnstone FC         3
# 1822                      Aberdeen          Ross County FC         0
# 1823                        Celtic              Motherwell        10
#
#       goal_against  goal_diff
# 1819             3          3
# 1820             2          0
# 1821             3          0
# 1822             5         -5
# 1823             2          8
#      country_name             league_name     period  stage        date  \
# 2409  Netherlands  Netherlands Eredivisie  2015/2016     34  2016-05-08
# 2410  Netherlands  Netherlands Eredivisie  2015/2016     34  2016-05-08
# 2411  Netherlands  Netherlands Eredivisie  2015/2016     34  2016-05-08
# 2412  Netherlands  Netherlands Eredivisie  2015/2016     34  2016-05-08
# 2413  Netherlands  Netherlands Eredivisie  2015/2016     34  2016-05-08
#
#          home_team      away_team  goal_for  goal_against  goal_diff
# 2409    FC Utrecht             AZ         1             3         -2
# 2410     Feyenoord         N.E.C.         1             0          1
# 2411  ADO Den Haag  SC Heerenveen         1             1          0
# 2412    PEC Zwolle            PSV         1             3         -2
# 2413    SC Cambuur      Excelsior         0             2         -2
#      country_name             league_name     period  stage        date  \
# 1657      Belgium  Belgium Jupiler League  2015/2016     30  2016-03-13
# 1658      Belgium  Belgium Jupiler League  2015/2016     30  2016-03-13
# 1659      Belgium  Belgium Jupiler League  2015/2016     30  2016-03-13
# 1660      Belgium  Belgium Jupiler League  2015/2016     30  2016-03-13
# 1661      Belgium  Belgium Jupiler League  2015/2016     30  2016-03-13
#
#                 home_team          away_team  goal_for  goal_against  \
# 1657          KV Mechelen  Standard de Liège         4             0
# 1658         KVC Westerlo   Waasland-Beveren         1             0
# 1659   Sporting Charleroi           KAA Gent         1             1
# 1660    Sint-Truidense VV   Sporting Lokeren         1             1
# 1661  Oud-Heverlee Leuven     Club Brugge KV         0             1
#
#       goal_diff
# 1657          4
# 1658          1
# 1659          0
# 1660          0
# 1661         -1

# %%
def des_stats(fun):
    for i in fun:
        print(i.country_name[0])
        print('')
        print('Mean')
        print('Home Goals =',i['goal_for'].mean())
        print('Away Goals =',i['goal_against'].mean())
        print('Goal Diff =',i['goal_diff'].mean())
        print('')
        print('Standard Deviation')
        print('Home Goals =',i['goal_for'].std())
        print('Away Goals =',i['goal_against'].std())
        print('Goal Diff =',i['goal_diff'].std())
        print('\n')

        
des_stats(matches)
# Out:
# Spain
#
# Mean
# Home Goals = 3.5148026315789473
# Away Goals = 2.437828947368421
# Goal Diff = 1.0769736842105264
#
# Standard Deviation
# Home Goals = 2.4976022645578757
# Away Goals = 1.807287510185563
# Goal Diff = 3.0353835333343344
#
#
# England
#
# Mean
# Home Goals = 3.310197368421053
# Away Goals = 2.5151315789473685
# Goal Diff = 0.7950657894736842
#
# Standard Deviation
# Home Goals = 2.267739028911996
# Away Goals = 1.963411951527559
# Goal Diff = 2.8020890755844543
#
#
# Italy
#
# Mean
# Home Goals = 3.2993039443155454
# Away Goals = 2.445475638051044
# Goal Diff = 0.8538283062645011
#
# Standard Deviation
# Home Goals = 2.161939317103179
# Away Goals = 1.7799428453311887
# Goal Diff = 2.599896593221579
#
#
# Germany
#
# Mean
# Home Goals = 3.218545751633987
# Away Goals = 2.489787581699346
# Goal Diff = 0.7287581699346405
#
# Standard Deviation
# Home Goals = 2.2653984749840546
# Away Goals = 1.8195847648870624
# Goal Diff = 2.8674501391133242
#
#
# Portugal
#
# Mean
# Home Goals = 2.5107066381156318
# Away Goals = 2.040149892933619
# Goal Diff = 0.47055674518201285
#
# Standard Deviation
# Home Goals = 1.9633473088551872
# Away Goals = 1.8421926279965604
# Goal Diff = 2.5835146089892245
#
#
# France
#
# Mean
# Home Goals = 2.9082236842105265
# Away Goals = 2.1648026315789473
# Goal Diff = 0.743421052631579
#
# Standard Deviation
# Home Goals = 1.926196197008439
# Away Goals = 1.6769770474369805
# Goal Diff = 2.4528370275517832
#
#
# Switzerland
#
# Mean
# Home Goals = 3.5663780663780664
# Away Goals = 2.727272727272727
# Goal Diff = 0.8391053391053391
#
# Standard Deviation
# Home Goals = 2.536433895891267
# Away Goals = 2.0073707305213593
# Goal Diff = 2.952221276012669
#
#
# Poland
#
# Mean
# Home Goals = 2.9343915343915343
# Away Goals = 2.1825396825396823
# Goal Diff = 0.7518518518518519
#
# Standard Deviation
# Home Goals = 2.019998552099517
# Away Goals = 1.7928780653718723
# Goal Diff = 2.3867264093648473
#
#
# Scotland
#
# Mean
# Home Goals = 3.1096491228070176
# Away Goals = 2.6008771929824563
# Goal Diff = 0.5087719298245614
#
# Standard Deviation
# Home Goals = 2.29837765953438
# Away Goals = 1.8913781623421493
# Goal Diff = 2.9514130655410487
#
#
# Netherlands
#
# Mean
# Home Goals = 3.519055509527755
# Away Goals = 2.56006628003314
# Goal Diff = 0.9589892294946147
#
# Standard Deviation
# Home Goals = 2.42112400786997
# Away Goals = 1.991152247532412
# Goal Diff = 3.0684239981556503
#
#
# Belgium
#
# Mean
# Home Goals = 3.1299638989169676
# Away Goals = 2.3598074608904933
# Goal Diff = 0.7701564380264742
#
# Standard Deviation
# Home Goals = 2.116693176801115
# Away Goals = 1.796517324247105
# Goal Diff = 2.5934897142360818

# %%
def result(fun):
    for i in fun:
        i['win'] = ((i['goal_diff']>0)*1)
        i['draw'] = ((i['goal_diff']==0)*1)
        i['lose'] = ((i['goal_diff']<0)*1)
        print(i.country_name[0])
        print('')
        print('win =' ,(i['win'].mean())*100,'%')
        print('draw =',(i['draw'].mean())*100,'%')
        print('lose =',(i['lose'].mean())*100,'%')
        print('\n')
    
result(matches)
# Out:
# Spain
#
# win = 55.328947368421055 %
# draw = 13.980263157894738 %
# lose = 30.69078947368421 %
#
#
# England
#
# win = 53.815789473684205 %
# draw = 16.348684210526315 %
# lose = 29.835526315789473 %
#
#
# Italy
#
# win = 53.49685117666556 %
# draw = 15.909844216108718 %
# lose = 30.59330460722572 %
#
#
# Germany
#
# win = 50.36764705882353 %
# draw = 16.544117647058822 %
# lose = 33.088235294117645 %
#
#
# Portugal
#
# win = 47.109207708779444 %
# draw = 20.931477516059957 %
# lose = 31.959314775160603 %
#
#
# France
#
# win = 52.86184210526316 %
# draw = 18.059210526315788 %
# lose = 29.078947368421055 %
#
#
# Switzerland
#
# win = 54.04040404040404 %
# draw = 11.688311688311687 %
# lose = 34.271284271284266 %
#
#
# Poland
#
# win = 52.38095238095239 %
# draw = 18.042328042328045 %
# lose = 29.57671957671958 %
#
#
# Scotland
#
# win = 47.14912280701755 %
# draw = 13.760964912280702 %
# lose = 39.08991228070175 %
#
#
# Netherlands
#
# win = 55.46810273405137 %
# draw = 14.95443247721624 %
# lose = 29.577464788732392 %
#
#
# Belgium
#
# win = 56.438026474127554 %
# draw = 13.959085439229844 %
# lose = 29.602888086642597 %

# %%
list_win = []
for i in matches:
    list_win.append(i['win'].mean())
#print(list_win) 


list_draw = []
for i in matches:
    list_draw.append(i['draw'].mean())
#print(list_draw)

list_lose = []
for i in matches:
    list_lose.append(i['lose'].mean())
    #print(list_lose)

list_countries = []

for i in matches:
    list_countries.append(i['country_name'][0])
    
#print(list_countries)

# %%
plt.figure(figsize = (15,7))

x = np.arange(len(list_win))

plt.bar(x,list_win,color='green', width = 0.5,label = 'Win')
plt.bar(x,list_draw,color= 'orange',bottom = list_win,width = 0.5,label = 'Draw')
plt.bar(x,list_lose,color= 'grey',bottom =[x+y for x,y in zip(list_win,list_draw)],width = 0.5,label = 'Lose')

#label

plt.xticks(x,list_countries, fontsize = 13)
plt.title('Home-Win-Draw-Lose',fontsize = 22)
plt.xlabel('Countries', fontsize = 16)
plt.ylabel('Ratio', fontsize = 16)


plt.legend(loc = 'upper right')

plt.show()

# %%
for i in matches:
    i['winner'] = np.where(i['win']==1, i['home_team'],i['away_team'])

# %%
top_teams_Spain = pd.crosstab(index = matches_Spain['winner'], columns = 'count').nlargest(10,'count')['count']
top_teams_Eng = pd.crosstab(index = matches_Eng['winner'], columns = 'count').nlargest(10,'count')['count']
top_teams_Ger = pd.crosstab(index = matches_Ger['winner'], columns = 'count').nlargest(10,'count')['count']
top_teams_France = pd.crosstab(index = matches_France['winner'], columns = 'count').nlargest(10,'count')['count']
top_teams_Italy = pd.crosstab(index = matches_Italy['winner'], columns = 'count').nlargest(10,'count')['count']
top_teams_Pol = pd.crosstab(index = matches_Pol['winner'], columns = 'count').nlargest(10,'count')['count']
top_teams_Swt = pd.crosstab(index = matches_Swt['winner'], columns = 'count').nlargest(10,'count')['count']
top_teams_Ned = pd.crosstab(index = matches_Ned['winner'], columns = 'count').nlargest(10,'count')['count']
top_teams_Scot = pd.crosstab(index = matches_Scot['winner'], columns = 'count').nlargest(10,'count')['count']
top_teams_Por = pd.crosstab(index = matches_Por['winner'], columns = 'count').nlargest(10,'count')['count']
top_teams_Bel = pd.crosstab(index = matches_Bel['winner'], columns = 'count').nlargest(10,'count')['count']

top_teams = [top_teams_Spain,top_teams_Eng,top_teams_Ger,top_teams_France,top_teams_Italy,top_teams_Pol,top_teams_Swt,
            top_teams_Ned,top_teams_Scot,top_teams_Por,top_teams_Bel]

# %%
plt.figure(figsize=(19,7))
#defining all the plots with respect to all the leagues
ax1 = plt.plot(top_teams_Spain,'o',label = 'Spain');
ax2 = plt.plot(top_teams_Eng,'o',label = 'England');
ax3 = plt.plot(top_teams_Ger,'o',label = 'Germany');
ax4 = plt.plot(top_teams_France,'o',label = 'France');
ax5 = plt.plot(top_teams_Italy,'o',label = 'Italy');
ax6 = plt.plot(top_teams_Pol,'o',label = 'Poland');
ax7 = plt.plot(top_teams_Swt,'o',label = 'Switzerland');
ax8 = plt.plot(top_teams_Ned,'o',label = 'Netherlands');
ax9 = plt.plot(top_teams_Scot,'o',label = 'Scotland');
ax10 = plt.plot(top_teams_Por,'o',label = 'Portugal');
ax11 = plt.plot(top_teams_Bel,'ko',label = 'Belgium');
plt.legend(loc = 'best');
plt.title('Top Teams in Europe', fontsize= 20)
plt.xlabel('Leagues',fontsize = 15)
plt.ylabel('Matches Won',fontsize = 15)

#Annotations for to Top Ten Teams
plt.annotate('Barcelona',(1,265))
plt.annotate('Real Madrid',(2,252))
plt.annotate('Celtic',(81,245))
plt.annotate('Man United',(11,233))
plt.annotate('Juventus',(41,225))
plt.annotate('Bayern Munich',(21,223))
plt.annotate('PSG',(31,219))
plt.annotate('Man City',(12,218))
plt.annotate('FC Basel',(61,218))
plt.annotate('Ajax',(71,216))
# Out:
# Text(71, 216, 'Ajax')

# %%
plt.figure(figsize=(15, 7))
ax1 = sns.kdeplot(top_teams_Spain, label='La Liga', fill=True)
ax2 = sns.kdeplot(top_teams_Eng, label='EPL', fill=True)
ax3 = sns.kdeplot(top_teams_Ger, label='Bundesliga', fill=True)
ax4 = sns.kdeplot(top_teams_France, label='League 1', fill=True)
ax5 = sns.kdeplot(top_teams_Italy, label='Serie A', fill=True)

plt.title('Distribution Plot to show the Competitiveness in the Top 5 Leagues in Europe', fontsize=16)
plt.xlabel('Matches Won', fontsize=14)
plt.ylabel('KDE', fontsize=14)
plt.legend()

plt.show()
